# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_data.csv")

# %%
df.isnull().sum()
# Out:
# id         0
# name       1
# age        3
# country    1
# gender     1
# income     1
# dtype: int64

# %%
df.isnull()
# Out:
#        id   name    age  country  gender  income
# 0   False  False  False    False   False   False
# 1   False  False  False    False   False   False
# 2   False  False   True    False   False   False
# 3   False  False   True    False   False   False
# 4   False  False  False    False   False    True
# 5   False  False  False    False   False   False
# 6   False   True  False    False   False   False
# 7   False  False  False     True   False   False
# 8   False  False  False    False   False   False
# 9   False  False   True    False   False   False
# 10  False  False  False    False    True   False

# %%
df.duplicated()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df2 = df.copy()
df2["tax"] = df2["income"].apply(lambda x: "20%" if x >= 50000 else "10%")
df2
# Out:
#     id          name   age country   gender   income  tax
# 0    1      John Doe  29.0     USA     Male  55000.0  20%
# 1    1      John Doe  29.0     USA     Male  55000.0  20%
# 2    2    Jane Smith   NaN  Canada   Female  62000.0  20%
# 3    3          Alex   NaN     USA  Unknown  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain   Female      NaN  10%
# 5    5        Li Wei  27.0   China     Male  51000.0  20%
# 6    6           NaN  45.0   India   Female  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0  20%
# 8    8    Rachel Lee  29.0     USA   Female  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0  10%
# 10  10   Emily Davis  31.0     USA      NaN  58000.0  20%

# %%
gender_map={"Male" : "M" , "Female" : "F" , "Unknown" : "U"}
df2["gender"] = df2["gender"].map(gender_map)

# %%
df2
# Out:
#     id          name   age country gender   income  tax
# 0    1      John Doe  29.0     USA      M  55000.0  20%
# 1    1      John Doe  29.0     USA      M  55000.0  20%
# 2    2    Jane Smith   NaN  Canada      F  62000.0  20%
# 3    3          Alex   NaN     USA      U  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain      F      NaN  10%
# 5    5        Li Wei  27.0   China      M  51000.0  20%
# 6    6           NaN  45.0   India      F  73000.0  20%
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0  20%
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0  10%
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%

# %%
df2.assign(new_income = df2["income"]*1.1)
# Out:
#     id          name   age country gender   income  tax  new_income
# 0    1      John Doe  29.0     USA      M  55000.0  20%     60500.0
# 1    1      John Doe  29.0     USA      M  55000.0  20%     60500.0
# 2    2    Jane Smith   NaN  Canada      F  62000.0  20%     68200.0
# 3    3          Alex   NaN     USA      U  47000.0  10%     51700.0
# 4    4  Maria Garcia  34.0   Spain      F      NaN  10%         NaN
# 5    5        Li Wei  27.0   China      M  51000.0  20%     56100.0
# 6    6           NaN  45.0   India      F  73000.0  20%     80300.0
# 7    7    Ahmed Khan  38.0     NaN      M  68000.0  20%     74800.0
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%     68200.0
# 9    9   Carlos Ruiz   NaN  Mexico      M  45000.0  10%     49500.0
# 10  10   Emily Davis  31.0     USA    NaN  58000.0  20%     63800.0

# %%
df.sort_values("income")
# Out:
#     id          name   age country   gender   income
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 0    1      John Doe  29.0     USA     Male  55000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN

# %%
df2=df2.ffill()

# %%
df2.sort_index()
# Out:
#     id          name   age country gender   income  tax
# 0    1      John Doe  29.0     USA      M  55000.0  20%
# 1    1      John Doe  29.0     USA      M  55000.0  20%
# 2    2    Jane Smith  29.0  Canada      F  62000.0  20%
# 3    3          Alex  29.0     USA      U  47000.0  10%
# 4    4  Maria Garcia  34.0   Spain      F  47000.0  10%
# 5    5        Li Wei  27.0   China      M  51000.0  20%
# 6    6        Li Wei  45.0   India      F  73000.0  20%
# 7    7    Ahmed Khan  38.0   India      M  68000.0  20%
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%
# 9    9   Carlos Ruiz  29.0  Mexico      M  45000.0  10%
# 10  10   Emily Davis  31.0     USA      M  58000.0  20%

# %%
df2=df2.reset_index(drop=True)

# %%
df2["Rank"]=df2["income"].rank(ascending=False , method="min")
df2
# Out:
#     id          name   age country gender   income  tax  Rank
# 0    1      John Doe  29.0     USA      M  55000.0  20%   6.0
# 1    1      John Doe  29.0     USA      M  55000.0  20%   6.0
# 2    2    Jane Smith  29.0  Canada      F  62000.0  20%   3.0
# 3    3          Alex  29.0     USA      U  47000.0  10%   9.0
# 4    4  Maria Garcia  34.0   Spain      F  47000.0  10%   9.0
# 5    5        Li Wei  27.0   China      M  51000.0  20%   8.0
# 6    6        Li Wei  45.0   India      F  73000.0  20%   1.0
# 7    7    Ahmed Khan  38.0   India      M  68000.0  20%   2.0
# 8    8    Rachel Lee  29.0     USA      F  62000.0  20%   3.0
# 9    9   Carlos Ruiz  29.0  Mexico      M  45000.0  10%  11.0
# 10  10   Emily Davis  31.0     USA      M  58000.0  20%   5.0

# %%
df2.columns
# Out:
# Index(['id', 'name', 'age', 'country', 'gender', 'income', 'tax', 'Rank'], dtype='object')

# %%
df2[['id', 'name', 'age', 'country', 'gender', 'income', 'Rank','tax']]
# Out:
#     id          name   age country gender   income  Rank  tax
# 0    1      John Doe  29.0     USA      M  55000.0   6.0  20%
# 1    1      John Doe  29.0     USA      M  55000.0   6.0  20%
# 2    2    Jane Smith  29.0  Canada      F  62000.0   3.0  20%
# 3    3          Alex  29.0     USA      U  47000.0   9.0  10%
# 4    4  Maria Garcia  34.0   Spain      F  47000.0   9.0  10%
# 5    5        Li Wei  27.0   China      M  51000.0   8.0  20%
# 6    6        Li Wei  45.0   India      F  73000.0   1.0  20%
# 7    7    Ahmed Khan  38.0   India      M  68000.0   2.0  20%
# 8    8    Rachel Lee  29.0     USA      F  62000.0   3.0  20%
# 9    9   Carlos Ruiz  29.0  Mexico      M  45000.0  11.0  10%
# 10  10   Emily Davis  31.0     USA      M  58000.0   5.0  20%

# %%
df=pd.read_csv("raw_data.csv")

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df.columns
# Out:
# Index(['id', 'name', 'age', 'country', 'gender', 'income'], dtype='object')

# %%
df[['name', 'age', 'country', 'gender', 'income' , 'id']]
# Out:
#             name   age country   gender   income  id
# 0       John Doe  29.0     USA     Male  55000.0   1
# 1       John Doe  29.0     USA     Male  55000.0   1
# 2     Jane Smith   NaN  Canada   Female  62000.0   2
# 3           Alex   NaN     USA  Unknown  47000.0   3
# 4   Maria Garcia  34.0   Spain   Female      NaN   4
# 5         Li Wei  27.0   China     Male  51000.0   5
# 6            NaN  45.0   India   Female  73000.0   6
# 7     Ahmed Khan  38.0     NaN     Male  68000.0   7
# 8     Rachel Lee  29.0     USA   Female  62000.0   8
# 9    Carlos Ruiz   NaN  Mexico     Male  45000.0   9
# 10   Emily Davis  31.0     USA      NaN  58000.0  10

# %%
df2=df.copy()

new_col_order=[col for col in df2.columns if col !="id"] + ["id"]
df2[new_col_order]

# %%
df2=df.copy()

# %%
df2 =df2.drop_duplicates()

# %%
df2 = df2.fillna(0)

# %%
df2= df2.sort_values("income" , ascending=False)

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#    id          name   age country   gender   income
# 0   6             0  45.0   India   Female  73000.0
# 1   7    Ahmed Khan  38.0       0     Male  68000.0
# 2   8    Rachel Lee  29.0     USA   Female  62000.0
# 3   2    Jane Smith   0.0  Canada   Female  62000.0
# 4  10   Emily Davis  31.0     USA        0  58000.0
# 5   1      John Doe  29.0     USA     Male  55000.0
# 6   5        Li Wei  27.0   China     Male  51000.0
# 7   3          Alex   0.0     USA  Unknown  47000.0
# 8   9   Carlos Ruiz   0.0  Mexico     Male  45000.0
# 9   4  Maria Garcia  34.0   Spain   Female      0.0

# %%
df2.to_csv("sorted_data.csv")

# %%
melted_data= df2.melt(
    id_vars=["name","age","country"],
    value_vars=["gender","income"],
    var_name="better_specie",
    value_name="moneyy"
)

# %%
melted_data
# Out:
#             name   age country better_specie   moneyy
# 0              0  45.0   India        gender   Female
# 1     Ahmed Khan  38.0       0        gender     Male
# 2     Rachel Lee  29.0     USA        gender   Female
# 3     Jane Smith   0.0  Canada        gender   Female
# 4    Emily Davis  31.0     USA        gender        0
# 5       John Doe  29.0     USA        gender     Male
# 6         Li Wei  27.0   China        gender     Male
# 7           Alex   0.0     USA        gender  Unknown
# 8    Carlos Ruiz   0.0  Mexico        gender     Male
# 9   Maria Garcia  34.0   Spain        gender   Female
# 10             0  45.0   India        income  73000.0
# 11    Ahmed Khan  38.0       0        income  68000.0
# 12    Rachel Lee  29.0     USA        income  62000.0
# 13    Jane Smith   0.0  Canada        income  62000.0
# 14   Emily Davis  31.0     USA        income  58000.0
# 15      John Doe  29.0     USA        income  55000.0
# ...

# %%
pivoted_data=melted_data.pivot(
    index=["name","age","country"],
    columns="better_specie",
    values="moneyy"
)

# %%
pivoted_data
# Out:
# better_specie               gender   income
# name         age  country
# 0            45.0 India     Female  73000.0
# Ahmed Khan   38.0 0           Male  68000.0
# Alex         0.0  USA      Unknown  47000.0
# Carlos Ruiz  0.0  Mexico      Male  45000.0
# Emily Davis  31.0 USA            0  58000.0
# Jane Smith   0.0  Canada    Female  62000.0
# John Doe     29.0 USA         Male  55000.0
# Li Wei       27.0 China       Male  51000.0
# Maria Garcia 34.0 Spain     Female      0.0
# Rachel Lee   29.0 USA       Female  62000.0

# %%
df=pd.read_csv("IRIS.csv")

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.query("petal_length>4.5")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 58            6.6          2.9           4.6          1.3  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [63 rows x 5 columns]

# %%
my_specie="Iris-virginica"
df.query("petal_length>4.5 and species == @my_specie")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 101           5.8          2.7           5.1          1.9  Iris-virginica
# 102           7.1          3.0           5.9          2.1  Iris-virginica
# 103           6.3          2.9           5.6          1.8  Iris-virginica
# 104           6.5          3.0           5.8          2.2  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 107           7.3          2.9           6.3          1.8  Iris-virginica
# 108           6.7          2.5           5.8          1.8  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
# 110           6.5          3.2           5.1          2.0  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 112           6.8          3.0           5.5          2.1  Iris-virginica
# ...

# %%
df.groupby("species")["sepal_length"].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepal_length, dtype: float64

# %%
df.groupby()

# %%
df2["species"]

# %%
df.groupby("species")["petal_width"].max()
# Out:
# species
# Iris-setosa        0.6
# Iris-versicolor    1.8
# Iris-virginica     2.5
# Name: petal_width, dtype: float64

# %%
df.groupby("species")["sepal_width"].std()
# Out:
# species
# Iris-setosa        0.381024
# Iris-versicolor    0.313798
# Iris-virginica     0.322497
# Name: sepal_width, dtype: float64

# %%
df["petal_ratio"]=df["petal_length"]/df["petal_width"]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# ...

# %%
df.groupby("species")["petal_ratio"].mean()
# Out:
# species
# Iris-setosa        7.078000
# Iris-versicolor    3.242837
# Iris-virginica     2.780662
# Name: petal_ratio, dtype: float64

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sex="female"
df.query("Sex==@sex and Fare>30")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 25            26         1       3
# 31            32         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Pclass")["Survived"].count() / df["Survived"].count() * 100
# Out:
# Pclass
# 1    24.242424
# 2    20.650954
# 3    55.106622
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64
